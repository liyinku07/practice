# %%
app_packages=['com.dreamgames.royalmatch','com.whatsapp','com.zzkko','com.instagram.android','com.snapchat.android']

# %%
pip install --upgrade google_play_scraper
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tqdm #安裝tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from tqdm import tqdm #進度條

from google_play_scraper import Sort, reviews, app


app_infos = []

for ap in tqdm(app_packages):
  info = app(ap, lang='zh-tw', country='tw')
  del info['comments']
  app_infos.append(info)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.96it/s]

# %%
pd.set_option('display.max_columns',None)
app_infos_df=pd.DataFrame(app_infos)
app_infos_df
# Out:
#                 title                                        description  \
# 0         Royal Match  Welcome to Royal Match, the king of puzzle gam...
# 1  WhatsApp Messenger  Meta 旗下的 WhatsApp\r\n\r\nWhatsApp Messenger 是專...
# 2    SHEIN購物：最熱門的時尚趨勢  現在介紹SHEIN移動應用程序！您喜歡我們網站的一切，現在觸手可及。\r\nSHEIN 是一...
# 3           Instagram  讓用戶與喜愛的人事物拉近距離 — Facebook 旗下的 Instagram\r\n\r\...
# 4            Snapchat  Snapchat 是與親友分享生活時刻快速有趣的方式 👻\r\n\r\n拍攝 Snap\r\...
#
#                                      descriptionHTML  \
# 0  Welcome to Royal Match, the king of puzzle gam...
# 1  Meta 旗下的 WhatsApp<br><br>WhatsApp Messenger 是專...
# 2  現在介紹SHEIN移動應用程序！您喜歡我們網站的一切，現在觸手可及。<br>SHEIN 是一...
# 3  讓用戶與喜愛的人事物拉近距離 — Facebook 旗下的 Instagram<br><br...
# 4  Snapchat 是與親友分享生活時刻快速有趣的方式 👻<br><br>拍攝 Snap<br...
#
#                        summary        installs  minInstalls  realInstalls  \
# 0        通過解決沿途的謎題來裝飾羅伯特國王的城堡！     50,000,000+     50000000      51620583
# ...

# %%
len(app_packages)
# Out:
# 5
